# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
def scrap_anime_review(base_url):
	reviews = []

	# Mulai dengan URL awal
	url = base_url

	while url:
		print(f"Mengambil halaman: {url}")
		response = requests.get(url)

		if response.status_code != 200:
			print(f"Gagal mengambil halaman: {url}, status code: {response.status_code}")
			break

		soup = BeautifulSoup(response.text, 'html.parser')

		# Ambil semua ulasan di halaman ini
		for item in soup.find_all(class_='review-element js-review-element'):
			review_body = item.find(class_='text')
			if review_body:
				review = review_body.get_text(strip=True)
				reviews.append(review)

		# Cari URL halaman berikutnya
		next_button = soup.find(attrs={'data-ga-click-type': 'review-more-reviews'})
		if next_button:
			url = next_button['href']
		else:
			url = None  # Berhenti jika tidak ada halaman berikutnya

	return reviews
  
def scrap_all_anime_review(max_page=1):
	reviews = []
	page = 0

	# Mulai dengan URL awal
	url = "https://myanimelist.net/reviews.php?t=anime"

	while url and page < max_page:
		print(f"Mengambil halaman: {url}")
		response = requests.get(url)

		if response.status_code != 200:
			print(f"Gagal mengambil halaman: {url}, status code: {response.status_code}")
			break

		soup = BeautifulSoup(response.text, 'html.parser')

		# Ambil semua ulasan di halaman ini
		for item in soup.find_all(class_='review-element js-review-element'):
			# Ambil judul anime
			title_tag = item.find(attrs={'data-ga-click-type': 'review-anime-title'})
			title = title_tag.get_text(strip=True) if title_tag else "No Title"

			review_body = item.find(class_='text')
			review = review_body.get_text(strip=True) if review_body else "No Review"
			
			# Simpan ke dalam list
			reviews.append({"title": title, "review": review})

		page += 1

		# Cari URL halaman berikutnya
		next_button = soup.find('a', attrs={'data-ga-click-type': 'review-next'})
		if next_button:
			url = next_button['href']
		else:
			url = None  # Berhenti jika tidak ada halaman berikutnya

	return reviews

# %%
# Mengambil review dari halaman top anime reviews
max_pages = 100
top_anime_reviews = scrap_all_anime_review(max_pages)

# Simpan ke file CSV
if top_anime_reviews:
	df = pd.DataFrame(top_anime_reviews)
	csv_file = "../datasets/anime_reviews.csv"
	df.to_csv(csv_file, index=False)
	print(f"{len(df)} data berhasil disimpan ke {csv_file}")
else:
	print("Tidak ada data yang disimpan.")
# Out:
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=2
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=3
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=4
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=5
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=6
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=7
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=8
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=9
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=10
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=11
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=12
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=13
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=14
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=15
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=16
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=17
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=18
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=19
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=20
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=21
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=22
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=23
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=24
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=25
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=26
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=27
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=28
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=29
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=30
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=31
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=32
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=33
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=34
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=35
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=36
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=37
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=38
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=39
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=40
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=41
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=42
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=43
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=44
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=45
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=46
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=47
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=48
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=49
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=50
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=51
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=52
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=53
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=54
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=55
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=56
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=57
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=58
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=59
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=60
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=61
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=62
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=63
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=64
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=65
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=66
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=67
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=68
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=69
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=70
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=71
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=72
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=73
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=74
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=75
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=76
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=77
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=78
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=79
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=80
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=81
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=82
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=83
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=84
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=85
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=86
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=87
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=88
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=89
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=90
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=91
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=92
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=93
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=94
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=95
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=96
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=97
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=98
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=99
# Mengambil halaman: https://myanimelist.net/reviews.php?t=anime&filter_check=&filter_hide=&preliminary=on&spoiler=off&p=100
# 5000 data berhasil disimpan ke ../datasets/anime_reviews.csv

# %%
# URL awal
base_url = "https://myanimelist.net/anime/40333/Uzumaki/reviews"

# Panggil fungsi untuk mengambil semua ulasan
all_reviews = scrap_anime_review(base_url)

# Menyimpan hasil ke file CSV
if all_reviews:
	df = pd.DataFrame(all_reviews, columns=["review"])
	csv_file = "reviews.csv"
	df.to_csv(csv_file, index=False)
	print(f"Berhasil menyimpan {len(all_reviews)} ulasan ke file {csv_file}.")
else:
	print("Tidak ada ulasan yang berhasil diambil.")
